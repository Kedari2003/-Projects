# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\kunal\\Downloads\\Default_Fin.csv")
data
# Out:
#       Index  Employed  Bank Balance  Annual Salary  Defaulted?
# 0         1         1       8754.36      532339.56           0
# 1         2         0       9806.16      145273.56           0
# 2         3         1      12882.60      381205.68           0
# 3         4         1       6351.00      428453.88           0
# 4         5         1       9427.92      461562.00           0
# ...     ...       ...           ...            ...         ...
# 9995   9996         1       8538.72      635908.56           0
# 9996   9997         1       9095.52      235928.64           0
# 9997   9998         1      10144.92      703633.92           0
# 9998   9999         1      18828.12      440029.32           0
# 9999  10000         0       2411.04      202355.40           0
#
# [10000 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          10000 non-null  int64
#  1   Employed       10000 non-null  int64
#  2   Bank Balance   10000 non-null  float64
#  3   Annual Salary  10000 non-null  float64
#  4   Defaulted?     10000 non-null  int64
# dtypes: float64(2), int64(3)
# memory usage: 390.8 KB

# %%
data.columns
# Out:
# Index(['Index', 'Employed', 'Bank Balance', 'Annual Salary', 'Defaulted?'], dtype='object')

# %%
data.isnull().sum()
# Out:
# Index            0
# Employed         0
# Bank Balance     0
# Annual Salary    0
# Defaulted?       0
# dtype: int64

# %%
data.count()
# Out:
# Employed         10000
# Bank Balance     10000
# Annual Salary    10000
# Defaulted?       10000
# dtype: int64

# %%
# column Index is not imp so 
data.drop('Index',inplace = True, axis = 1)

# %%
data
# Out:
#       Employed  Bank Balance  Annual Salary  Defaulted?
# 0            1       8754.36      532339.56           0
# 1            0       9806.16      145273.56           0
# 2            1      12882.60      381205.68           0
# 3            1       6351.00      428453.88           0
# 4            1       9427.92      461562.00           0
# ...        ...           ...            ...         ...
# 9995         1       8538.72      635908.56           0
# 9996         1       9095.52      235928.64           0
# 9997         1      10144.92      703633.92           0
# 9998         1      18828.12      440029.32           0
# 9999         0       2411.04      202355.40           0
#
# [10000 rows x 4 columns]

# %%
data.describe()
# Out:
#            Employed  Bank Balance  Annual Salary    Defaulted?
# count  10000.000000  10000.000000   10000.000000  10000.000000
# mean       0.705600  10024.498524  402203.782224      0.033300
# std        0.455795   5804.579486  160039.674988      0.179428
# min        0.000000      0.000000    9263.640000      0.000000
# 25%        0.000000   5780.790000  256085.520000      0.000000
# 50%        1.000000   9883.620000  414631.740000      0.000000
# 75%        1.000000  13995.660000  525692.760000      0.000000
# max        1.000000  31851.840000  882650.760000      1.000000

# %%
data.corr()
# Out:
#                Employed  Bank Balance  Annual Salary  Defaulted?
# Employed       1.000000     -0.203578       0.753985   -0.035420
# Bank Balance  -0.203578      1.000000      -0.152243    0.350119
# Annual Salary  0.753985     -0.152243       1.000000   -0.019871
# Defaulted?    -0.035420      0.350119      -0.019871    1.000000

# %%
data['Defaulted?'] == 1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Defaulted?, Length: 10000, dtype: bool

# %%
data['Defaulted?'].value_counts()
# Out:
# Defaulted?
# 0    9667
# 1     333
# Name: count, dtype: int64

# %%
data[data['Defaulted?'] == 1].head(10)
# Out:
#      Employed  Bank Balance  Annual Salary  Defaulted?
# 136         0      17844.00      214252.80           1
# 173         0      26469.60      171257.88           1
# 201         0      21296.28      244314.12           1
# 206         1      22675.20      587474.04           1
# 209         0      22792.68      247862.40           1
# 241         0      18874.32      179162.16           1
# 243         1      23573.76      468655.08           1
# 263         1      18364.20      360045.84           1
# 341         1      19713.84      562283.40           1
# 345         1      23899.80      505600.44           1

# %%
data[data['Annual Salary'] >= 468655.08]
# Out:
#       Employed  Bank Balance  Annual Salary  Defaulted?
# 0            1       8754.36      532339.56           0
# 13           1       7280.88      539934.72           0
# 15           1       3434.76      540508.92           0
# 16           1          0.00      603183.72           0
# 18           1       5831.28      738793.32           0
# ...        ...           ...            ...         ...
# 9991         1       7905.60      657624.96           0
# 9992         1      13339.80      545888.16           0
# 9993         1      11266.08      679601.40           0
# 9995         1       8538.72      635908.56           0
# 9997         1      10144.92      703633.92           0
#
# [3751 rows x 4 columns]

# %%
k = data[data['Annual Salary'] >= 468655.08]

# %%
k
# Out:
#       Employed  Bank Balance  Annual Salary  Defaulted?
# 0            1       8754.36      532339.56           0
# 13           1       7280.88      539934.72           0
# 15           1       3434.76      540508.92           0
# 16           1          0.00      603183.72           0
# 18           1       5831.28      738793.32           0
# ...        ...           ...            ...         ...
# 9991         1       7905.60      657624.96           0
# 9992         1      13339.80      545888.16           0
# 9993         1      11266.08      679601.40           0
# 9995         1       8538.72      635908.56           0
# 9997         1      10144.92      703633.92           0
#
# [3751 rows x 4 columns]

# %%
k.count()
# Out:
# Employed         3751
# Bank Balance     3751
# Annual Salary    3751
# Defaulted?       3751
# dtype: int64

# %%
sns.countplot(data,x = 'Defaulted?')
# Out:
# <Axes: xlabel='Defaulted?', ylabel='count'>

# %%
sns.heatmap(data[['Employed', 'Bank Balance', 'Annual Salary', 'Defaulted?']].corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(data,y='Annual Salary',x='Bank Balance',hue='Defaulted?',alpha=0.5)
# Out:
# <Axes: xlabel='Bank Balance', ylabel='Annual Salary'>

# %%
default=data[data['Defaulted?']==1]

# %%
sns.scatterplot(default,y='Annual Salary',x='Bank Balance')
# Out:
# <Axes: xlabel='Bank Balance', ylabel='Annual Salary'>
